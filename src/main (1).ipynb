# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions import * 
from extrapolator import VarProIRLS
from extrap import VarProLinearized
pd.set_option('display.precision', 18)
pd.set_option('display.max_columns', None)
np.set_printoptions(precision=18)

# %%
# def upload_df1(file_path):
#   df = pd.read_csv(file_path)
#   df['basis size'] = df['basis size'].astype(int)

#   return df[2:]

# %%
be_1de = upload_df('/home/aldiyar/extrapolation/large-dataset/be_1De.xls')
be_1de = be_1de.drop(columns=['SO1', 'SO2'])
be_1de = be_1de.rename(columns={'Basis Size': 'basis size'})
be_1de_inf = be_1de.loc[be_1de['basis size'] == max(be_1de['basis size'])]
be_1de_init = be_1de.iloc[:-1]
be_1de_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_1De_err.xls')
be_1de_err = be_1de_err.drop(columns=['SO1', 'SO2'])

# %%
be_3de = upload_df('/home/aldiyar/extrapolation/large-dataset/be_3De.xls')
be_3de = be_3de.rename(columns={'Basis Size': 'basis size'})
be_3de_inf = be_3de.loc[be_3de['basis size'] == max(be_3de['basis size'])]
be_3de_init = be_3de.iloc[:-1]
be_3de_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_3De_err.xls')

# %%
be_3pe = upload_df('/home/aldiyar/extrapolation/large-dataset/be_3Pe.xls')
be_3pe = be_3pe.rename(columns={'Basis Size': 'basis size'})
be_3pe_inf = be_3pe.loc[be_3pe['basis size'] == max(be_3pe['basis size'])]
be_3pe_init = be_3pe.iloc[:-1]
be_3pe_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_3Pe_err.xls')

# %%
li_2se = upload_df('/home/aldiyar/extrapolation/large-dataset/Li_2Se.csv')
li_2se = li_2se.drop(columns = ['SO1', 'SO2'])
li_2se = li_2se.rename(columns= {'Basis Size': 'basis size'})
li_2se_inf = li_2se.loc[li_2se['basis size'] == max(li_2se['basis size'])]
li_2se_init = li_2se.iloc[:-1]
li_2se_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/li_2se_err.csv')

# %%
be_1se = upload_df('/home/aldiyar/extrapolation/large-dataset/Be_1Se.csv')
be_1se = be_1se.drop(columns = ['SO1', 'SO2'])
be_1se = be_1se.rename(columns= {'Basis Size': 'basis size'})
be_1se_inf = be_1se.loc[be_1se['basis size'] == max(be_1se['basis size'])]
be_1se_init = be_1se.iloc[:-1]
be_1se_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_1se_err.csv')

# %%
be_3po = upload_df('/home/aldiyar/extrapolation/large-dataset/Be_3Po.csv')
be_3po = be_3po.drop(columns = ['SO1', 'SO2'])
be_3po = be_3po.rename(columns= {'Basis Size': 'basis size'})
be_3po_inf = be_3po.loc[be_3po['basis size'] == max(be_3po['basis size'])]
be_3po_init = be_3po.iloc[:-1]
be_3po_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_3po_err.csv')

# %%
be_1po = upload_df('/home/aldiyar/extrapolation/large-dataset/Be_1Po.csv')
be_1po = be_1po.drop(columns = ['SO1', 'SO2'])
be_1po = be_1po.rename(columns= {'Basis Size': 'basis size'})
be_1po_inf = be_1po.loc[be_1po['basis size'] == max(be_1po['basis size'])]
be_1po_init = be_1po.iloc[:-1]
be_1po_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_1po_err.csv')

# %%
li_2po = upload_df('/home/aldiyar/extrapolation/large-dataset/Li_2Po.csv')
li_2po = li_2po.drop(columns = ['SO1', 'SO2'])
li_2po = li_2po.rename(columns= {'Basis Size': 'basis size'})
li_2po_inf = li_2po.loc[li_2po['basis size'] == max(li_2po['basis size'])]
li_2po_init = li_2po.iloc[:-1]
li_2po_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/li_2po_err.csv')

# %%
be_3se = upload_df('/home/aldiyar/extrapolation/large-dataset/Be_3Se.csv')
be_3se = be_3se.drop(columns = ['SO1', 'SO2'])
be_3se = be_3se.rename(columns= {'Basis Size': 'basis size'})
be_3se_inf = be_3se.loc[be_3se['basis size'] == max(be_3se['basis size'])]
be_3se_init = be_3se.iloc[:-1]
be_3se_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_3se_err.csv')

# %%
be_1se_1po = upload_df('/home/aldiyar/extrapolation/large-dataset/Be_1Se_1Po.xls')
be_1se_1po = be_1se_1po.rename(columns= {'Basis Size': 'basis size'})
be_1se_1po_inf = be_1se_1po.loc[be_1se_1po['basis size'] == max(be_1se_1po['basis size'])]
be_1se_1po_init = be_1se_1po[:-3]
be_1se_1po_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/be_1se_1po_err.csv')

# %%
li_2se_2po = upload_df('/home/aldiyar/extrapolation/large-dataset/Li_2Se_2Po.xls')
li_2se_2po = li_2se_2po.rename(columns= {'Basis Size': 'basis size'})
li_2se_2po_inf = li_2se_2po.loc[li_2se_2po['basis size'] == max(li_2se_2po['basis size'])]
li_2se_2po_init = li_2se_2po[:-3]
li_2se_2po_err = pd.read_csv('/home/aldiyar/extrapolation/large-dataset-err/li_2se_2po_err.csv')

# %%
be_3po_small = upload_df('/home/aldiyar/extrapolation/new-dataset/be_3po_test.csv')
be_3po_small = be_3po_small.rename(columns= {'Basis Size': 'basis size'})
be_3po_small_init = be_3po_small[:-2]
be_3po_small_inf = be_3po_small.iloc[[-2]]
be_3po_small_err = be_3po_small.loc[be_3po_small['basis size'] == max(be_3po_small['basis size'])]

# %%
solver = VarProLinearized(be_1de_init, 'basis size', 'drach_delta(r_1)', inf_df = be_1de_inf, err_df=be_1de_err, use_energy_b=True)
solver.fit_linearized(verbose=True)
solver.plot()
solver.plot_log()
# Out:
#  this trend is: True
# [use_energy_b] Fitting 'Energy' first to derive B for 'drach_delta(r_1)' [nonsingular (using B)] ...
#  this trend is: False
#   [B free]
# [exponential         ] B=    7.436977 (free)  C_scaled= -0.00102670  C=-14.40823715  A=    0.000073  R²(log)=0.992667  SSR=2.2214e-01
# [sqrt_exponential    ] B=    9.790734 (free)  C_scaled= -0.00267050  C=-14.40823720  A=    0.001626  R²(log)=0.999303  SSR=9.4577e-03
# [power_law           ] B=    2.844662 (free)  C_scaled= -0.00791594  C=-14.40823737  A=    0.000000  R²(log)=0.998897  SSR=6.2215e-02
# [use_energy_b]   exponential            B from Energy = 7.436977
# [use_energy_b]   sqrt_exponential       B from Energy = 9.790734
# [use_energy_b]   power_law              B from Energy = 2.844662
#   [B anchored to Energy fit]
# [exponential         ] B=    7.436977 (from Energy (B))  C_scaled=  1.00091028  C=  8.63806249  A=   -0.000453  R²(log)=0.990151  SSR=1.4228e-01
# ...

# %%
# solver = VarProIRLS(be_1po_init, 'basis size', 'Energy', inf_df = be_1po_inf, err_df=be_1po_err)
# solver.fit_irls(verbose=False)
# solver.plot()
# solver.plot_final_weights(model_type='power_law')

# %%
# fit_all_log(be_3pe_init, be_3pe_inf, be_3pe_err)

# %%
reference_values = pd.read_csv('/home/aldiyar/extrapolation/large-dataset/reference_vals.txt', delim_whitespace=True)
# Out:
# /tmp/ipykernel_2351/4049882052.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   reference_values = pd.read_csv('/home/aldiyar/extrapolation/large-dataset/reference_vals.txt', delim_whitespace=True)

# %%
# Assuming VarProLinearized is imported or defined above in your notebook

def extrapolate_system(df, system_name):
    """
    Extrapolates all expectation values for a single system's dataframe 
    using VarProLinearized and returns a list of dictionaries with the unscaled results.
    """
    # Dynamically determine the x-axis column (handling case variations)
    if "basis size" in df.columns:
        x_col = "basis size"
    elif "Basis Size" in df.columns:
        x_col = "Basis Size"
    else:
        x_col = df.columns[0]
        
    expectation_columns = [c for c in df.columns if c != x_col]
    rows = []

    for y_col in expectation_columns:
        
        # We must keep the Energy column in the cleaned dataframe if we want 
        # to use 'use_energy_b=True' to fix the B parameter.
        cols_to_keep = [x_col, y_col]
        if 'Energy' in df.columns and y_col != 'Energy':
            cols_to_keep.append('Energy')
            
        # Drop NaNs just for the specific columns we are fitting
        clean_df = df.dropna(subset=cols_to_keep).copy()
        
        if len(clean_df) < 4:  # Need minimum points to fit
            continue
            
        try:
            # Initialize the NEW Linearized solver. 
            # use_energy_b=True automatically handles the B and B/2 logic!
            solver = VarProLinearized(
                df=clean_df, 
                x_col=x_col, 
                y_col=y_col,
                use_energy_b=True
            )
            
            # Fit and COMPUTE UNCERTAINTIES
            results = solver.fit_linearized(verbose=False, compute_uq=True)
            
            row_data = {
                "system": system_name,
                "expectation_value": y_col,
            }
            
            # Extract and UNSCALE the results for each model
            for model in ['exponential', 'sqrt_exponential', 'power_law']:
                if model in results:
                    # Unscale C
                    C_scaled = results[model]['C']
                    C_unscaled = solver.y_min + solver.y_range * C_scaled
                    
                    # Unscale Uncertainty
                    sig_scaled = results[model].get('sigma_mc', np.nan)
                    sig_unscaled = solver.y_range * sig_scaled
                    
                    # Save to dictionary using names compatible with the ranking function
                    row_data[f"C_{model}"] = C_unscaled
                    row_data[f"unc_{model}"] = sig_unscaled
                    
            rows.append(row_data)
            
        except Exception as e:
            print(f"  [!] Failed {system_name} - {y_col}: {e}")

    return rows

# =====================================================================
# 1. Define your loaded dataframes in a dictionary
# =====================================================================
systems = {
    "infBe_1Po-01": be_1po_init,
    "infBe_1Se-01": be_1se_init,
    "infBe_3Po-01": be_3po_init,
    "infBe_3Se-01": be_3se_init,
    "infLi_2Po-01": li_2po_init,
    "infLi_2Se-01": li_2se_init,
    "infBe_1De-01": be_1de_init,
    'infBe_3De-01': be_3de_init,
    'infBe_3Pe-01': be_3pe_init,
}

# =====================================================================
# 2. Run the extrapolations
# =====================================================================
print("Running extrapolations...")
all_results = []
for sys_name, df in systems.items():
    print(f"  -> Processing {sys_name}...")
    sys_results = extrapolate_system(df, sys_name)
    all_results.extend(sys_results)

# Convert all collected results into a single DataFrame
extrapolated_df = pd.DataFrame(all_results)

# =====================================================================
# 3. Format Reference Data & Merge
# =====================================================================
# Assuming 'reference_values' is your loaded reference_vals.txt DataFrame
# Let's ensure the columns match what we expect before merging
if 'system' not in reference_values.columns:
    # Rename columns if it still has the raw text file headers
    reference_values = reference_values.rename(columns={
        'system': 'system',
        'expectation_value': 'expectation_value',
        'ref_value': 'ref_value',  # Update if named differently
        'uncertainty': 'ref_uncertainty'
    })

# Merge the extrapolations into the reference dataframe
benchmark_df = pd.merge(
    reference_values,
    extrapolated_df,
    on=["system", "expectation_value"],
    how="left"
)

# Optional: Fill missing extrapolations with NaN instead of 0 
# (NaN is safer for the ranking math so it skips it instead of assuming 0 error)
benchmark_df = benchmark_df.fillna(np.nan)

print("\nDone! Preview of merged DataFrame:")
display(benchmark_df.head())

# Now benchmark_df is ready to be passed directly into apply_continuous_ranking(benchmark_df)
# Out:
# Running extrapolations...
#   -> Processing infBe_1Po-01...
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#   -> Processing infBe_1Se-01...
#  this trend is: False
#  this trend is: False
#  this trend is: False
# ...

# %%
benchmark_df = benchmark_df.drop(['unc_exponential', 'unc_sqrt_exponential', 'unc_power_law'], axis = 1)

# %%
benchmark_df.dropna(inplace= True)

# %%
benchmark_df.rename(columns = {'C_exponential': 'exp_inf', 'C_sqrt_exponential': 'exp_sq_inf', 'C_power_law': 'power_inf'}, inplace = True)

# %%
benchmark_df
# Out:
#            system  expectation_value               ref_value  \
# 0    infBe_1Po-01             Energy  -14.473451386869198743
# 1    infBe_1Po-01                 MV -266.659088807117598208
# 2    infBe_1Po-01           drach_MV -266.664462793425059317
# 3    infBe_1Po-01                 OO   -0.812091476559140046
# 4    infBe_1Po-01            1/r^2_1   14.216540761971746321
# ..            ...                ...                     ...
# 153  infLi_2Se-01        delta(r_12)    0.181442143819717489
# 154  infLi_2Se-01   drach_delta(r_1)    4.614203618764592285
# 155  infLi_2Se-01  drach_delta(r_12)    0.181441544289981410
# 156  infLi_2Se-01         prval(r_1) -102.770256511564326729
# 157  infLi_2Se-01        prval(r_12)    0.091079437718323997
#
#               uncertainty          source                 exp_inf  \
# 0    0.000000001571315522  our_calc_16400  -14.473451265509551078
# 1    0.000015943136020269  our_calc_16400 -266.643608326787500573
# ...

# %%
def score_ranks(df):
    df = df.copy()

    # --- Process each row individually to calculate scores and then rank ---
    all_ranks = []
    for index, row in df.iterrows():
        model_scores = {}
        
        ref_value = row['ref_value']
        ref_unc = row['uncertainty']
        
        # --- 1. Calculate Absolute Errors for each model ---
        errors = {}
        for model_key in ["exp", "exp_sq", "power"]:
            pred_val = row[f'{model_key}_inf']
            errors[model_key] = np.abs(pred_val - ref_value)
            
        # --- 2. Determine Error Priorities (min, med, max) ---
        min_err = min(errors.values())
        max_err = max(errors.values())
        eps = 1e-12  # Tolerance for floating point ties
        
        error_priority = {}
        for model_key, err in errors.items():
            if np.abs(err - min_err) < eps:
                error_priority[model_key] = 'min'
            elif np.abs(err - max_err) < eps:
                error_priority[model_key] = 'max'
            else:
                error_priority[model_key] = 'med'
                
        # Edge case: If all three are identical, they are all 'min'
        if all(v == 'max' for v in error_priority.values()):
            error_priority = {k: 'min' for k in error_priority.keys()}

        # --- 3. Evaluate the 6-Tier Discrete Logic ---
        # Lower score is better to match the sorting logic below
        tier_mapping = {
            ('min', True):  1,  # Rank 1 (Best): Lowest error, hits uncertainty bounds
            ('min', False): 2,  # Rank 2: Lowest error, misses bounds
            ('med', True):  3,  # Rank 3: Medium error, hits bounds
            ('med', False): 4,  # Rank 4: Medium error, misses bounds
            ('max', True):  5,  # Rank 5: Highest error, hits bounds
            ('max', False): 6   # Rank 6 (Worst): Highest error, misses bounds
        }
        
        for model_key in ["exp", "exp_sq", "power"]:
            # Check Encapsulation: Is error within the Reference Uncertainty?
            encapsulates = errors[model_key] <= ref_unc
            priority = error_priority[model_key]
            
            # Base discrete tier score (1 to 6)
            base_score = tier_mapping[(priority, encapsulates)]
            
            # Tie-breaker: If two models land in the same discrete tier, 
            # add a tiny fraction of their relative error so the sorting is deterministic.
            tie_breaker = (errors[model_key] / (max_err + 1e-30)) * 0.1
            
            # --- Combine into the Final Score ---
            final_score = base_score + tie_breaker
            model_scores[model_key] = final_score
        
        # --- Sort models by their score (lowest is best) to determine rank ---
        sorted_models = sorted(model_scores.items(), key=lambda item: item[1])
        
        # --- Assign ranks (1, 2, 3) based on the sorted order ---
        row_ranks = {model_name: rank + 1 for rank, (model_name, score) in enumerate(sorted_models)}
        all_ranks.append(row_ranks)

    # --- Add the final rank columns to the DataFrame ---
    df['rank_exp'] = [r.get('exp') for r in all_ranks]
    df['rank_exp_sq'] = [r.get('exp_sq') for r in all_ranks]
    df['rank_power'] = [r.get('power') for r in all_ranks]
    
    return df

# %%
df_ranked = score_ranks(benchmark_df)
# df_ranked.drop(columns=['exp_delta', 'exp_sq_delta', 'power_delta'], inplace = True)
df_ranked
# Out:
#            system  expectation_value               ref_value  \
# 0    infBe_1Po-01             Energy  -14.473451386869198743
# 1    infBe_1Po-01                 MV -266.659088807117598208
# 2    infBe_1Po-01           drach_MV -266.664462793425059317
# 3    infBe_1Po-01                 OO   -0.812091476559140046
# 4    infBe_1Po-01            1/r^2_1   14.216540761971746321
# ..            ...                ...                     ...
# 153  infLi_2Se-01        delta(r_12)    0.181442143819717489
# 154  infLi_2Se-01   drach_delta(r_1)    4.614203618764592285
# 155  infLi_2Se-01  drach_delta(r_12)    0.181441544289981410
# 156  infLi_2Se-01         prval(r_1) -102.770256511564326729
# 157  infLi_2Se-01        prval(r_12)    0.091079437718323997
#
#               uncertainty          source                 exp_inf  \
# 0    0.000000001571315522  our_calc_16400  -14.473451265509551078
# 1    0.000015943136020269  our_calc_16400 -266.643608326787500573
# ...

# %%
print(df_ranked['rank_exp'].value_counts())
print(df_ranked['rank_exp_sq'].value_counts())
print(df_ranked['rank_power'].value_counts())
# Out:
# rank_exp
# 3    98
# 2    27
# 1    21
# Name: count, dtype: int64
# rank_exp_sq
# 2    107
# 1     39
# Name: count, dtype: int64
# rank_power
# 1    86
# 3    48
# 2    12
# Name: count, dtype: int64

# %%
import seaborn as sns


# 1. Safely handle the MultiIndex if system and expectation_value are in the index
df_plot = df_ranked.copy()
if 'system' not in df_plot.columns:
    df_plot = df_plot.reset_index()

# 2. Melt to long format using lowercase column names
df_long = df_plot.melt(
    id_vars=["system", "expectation_value"],
    value_vars=["rank_exp", "rank_exp_sq", "rank_power"],
    var_name="method", value_name="rank"
)

# Clean method names
df_long["method"] = df_long["method"].str.replace("rank_", "")

# Full list of expectation values to ensure consistent ordering
all_expectations = [
    'Energy', 'MV', 'drach_MV', 'OO', '1/r^2_1', '1/r^2_12', '1/r_1',
    '1/r_12', 'r_1', 'r_12', 'r^2_1', 'r^2_12', 'delta(r_1)', 'delta(r_12)',
    'drach_delta(r_1)', 'drach_delta(r_12)', 'prval(r_1)', 'prval(r_12)'
]

# 3. Setup subplots per system
systems = df_long["system"].unique()
n_systems = len(systems)

fig, axes = plt.subplots(
    n_systems, 1, 
    figsize=(8, max(4 * n_systems, 0.4 * len(all_expectations)))
)

# Make axes iterable even if n_systems=1
if n_systems == 1:
    axes = [axes]

for ax, system in zip(axes, systems):
    # Pivot data for this specific system
    pivot = df_long[df_long["system"] == system].pivot(
        index="expectation_value", columns="method", values="rank"
    )
    
    # Ensure all rows exist and are in the exact same order
    pivot = pivot.reindex(all_expectations)

    # Plot heatmap (fmt="g" for integers, viridis_r to make Rank 1 dark/distinct)
    sns.heatmap(
        pivot, cmap="viridis_r", annot=True, fmt="g", cbar=False, ax=ax,
        linewidths=0.5, linecolor='lightgray'
    )
    
    ax.set_title(f"System: {system}", pad=10, fontweight="bold")
    ax.set_ylabel("Expectation Value")
    ax.set_xlabel("")
    
    # Improve tick appearance
    ax.tick_params(axis="x", labelrotation=0)
    ax.tick_params(axis="y", labelrotation=0)

plt.tight_layout()
plt.show()

# %%
# Assuming you have a dataframe `df_be_1de` and an error dataframe `err_be_1de`
fit_and_plot_system(
    df=be_3po_init, 
    system_name='be_3po', 
    x_col='basis size', 
    err_df=be_3po_err, 
    inf_df=be_3po_inf,
    save_pdf=True
)
# Out:
# Fitting 18 columns for Be($^3P^o$)...
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: True
#  this trend is: False
#  this trend is: False
#  this trend is: False
#  this trend is: True
#  this trend is: False
# Saved plot to be_3po_fits.pdf
